# %% [markdown]
# ##Importing the libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Flatten, GlobalMaxPooling1D

# %% [markdown]
# ##Importing our pre-cleaned dataset

# %%
dataset = pd.read_csv('Customer_Queries_1.csv')
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# Encoding our dependent variable

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y)

# %% [markdown]
# ## Data Cleaning

# %%
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"\'bout", " about", text)
    text = re.sub(r"[-()\'|/<>,`~!#$%^&*:;.?{}]", "", text)
    return text

# %%
for i in range(len(X)):
    X[i][0] = clean_text(X[i][0]).replace('"','')

# %%
import nltk
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range(len(X)):
    query = X[i][0].split()
    ps = PorterStemmer()
    query = [ps.stem(word) for word in query]
    query = " ".join(query)
    corpus.append(query)

# %%
print(corpus)

# %% [markdown]
# Tokenizing our inputs

# %%
tokenizer = Tokenizer(num_words = 2000)
tokenizer.fit_on_texts(corpus)
train = tokenizer.texts_to_sequences(corpus)

# %% [markdown]
# Padding our input to make the training easy

# %%
x_train = pad_sequences(train)

# %%
input_shape = x_train.shape[1]
unique_words = len(tokenizer.word_index)
output_length = le.classes_.shape[0]

# %%
print(output_length)
# Out:
# 19

# %% [markdown]
# ## Training our ChatBot

# %%
model = tf.keras.Sequential()
model.add(Input(shape=(input_shape,)))
model.add(Embedding(unique_words+1, 10, input_length= (input_shape,)))
model.add(LSTM(10, return_sequences=True))
model.add(Flatten())
model.add(Dense(units= 19, activation='relu'))
model.add(Dense(units= 19, activation='relu'))
model.add(Dense(units= 19, activation='relu'))
model.add(Dense(units= output_length, activation='softmax'))

# %%
model.compile(loss = "sparse_categorical_crossentropy", optimizer ='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 31/31 [==============================] - 3s 8ms/step - loss: 2.8575 - accuracy: 0.1395
# Epoch 2/500
# 31/31 [==============================] - 0s 8ms/step - loss: 2.5818 - accuracy: 0.2308
# Epoch 3/500
# 31/31 [==============================] - 0s 12ms/step - loss: 2.4808 - accuracy: 0.2308
# Epoch 4/500
# 31/31 [==============================] - 0s 12ms/step - loss: 2.4139 - accuracy: 0.2308
# Epoch 5/500
# 31/31 [==============================] - 0s 13ms/step - loss: 2.2835 - accuracy: 0.2318
# Epoch 6/500
# 31/31 [==============================] - 0s 14ms/step - loss: 2.1219 - accuracy: 0.2790
# Epoch 7/500
# 31/31 [==============================] - 0s 14ms/step - loss: 1.9610 - accuracy: 0.3323
# Epoch 8/500
# 31/31 [==============================] - 0s 16ms/step - loss: 1.7658 - accuracy: 0.4215
# Epoch 9/500
# 31/31 [==============================] - 0s 14ms/step - loss: 1.5032 - accuracy: 0.4759
# Epoch 10/500
# 31/31 [==============================] - 0s 15ms/step - loss: 1.2423 - accuracy: 0.5405
# Epoch 11/500
# 31/31 [==============================] - 0s 13ms/step - loss: 1.0391 - accuracy: 0.6400
# Epoch 12/500
# 31/31 [==============================] - 0s 14ms/step - loss: 0.9003 - accuracy: 0.6595
# Epoch 13/500
# 31/31 [==============================] - 0s 13ms/step - loss: 0.7929 - accuracy: 0.7108
# Epoch 14/500
# 31/31 [==============================] - 0s 14ms/step - loss: 0.7167 - accuracy: 0.7262
# Epoch 15/500
# 31/31 [==============================] - 0s 16ms/step - loss: 0
500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1979 - accuracy: 0.8882
# Epoch 59/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1968 - accuracy: 0.8862
# Epoch 60/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1953 - accuracy: 0.8810
# Epoch 61/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1891 - accuracy: 0.8779
# Epoch 62/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1842 - accuracy: 0.8995
# Epoch 63/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1882 - accuracy: 0.8851
# Epoch 64/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1855 - accuracy: 0.8831
# Epoch 65/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1897 - accuracy: 0.8759
# Epoch 66/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1877 - accuracy: 0.8923
# Epoch 67/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1874 - accuracy: 0.8872
# Epoch 68/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1821 - accuracy: 0.8903
# Epoch 69/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1896 - accuracy: 0.8862
# Epoch 70/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1817 - accuracy: 0.8944
# Epoch 71/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1995 - accuracy: 0.8841
# Epoch 72/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.2546 - accuracy: 0.8656
# Epoch 73/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1987 - accuracy: 0.8821
# Epoch 74/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1792 - accuracy: 0.8831
# Epoch 75/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1752 - accuracy: 0.8964
# Epoch 76/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1915 - accuracy: 0.8800
# Epoch 77/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1776 - accuracy: 0.8923
# Epoch 78/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1738 - accuracy: 0.8974
# Epoch 79/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1839 - accuracy: 0.8821
# Epoch 80/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1798 - accuracy: 0.8903
# Epoch 81/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1729 - accuracy: 0.8995
# Epoch 82/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1881 - accuracy: 0.8944
# Epoch 83/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1705 - accuracy: 0.9026
# Epoch 84/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1775 - accuracy: 0.8985
# Epoch 85/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1846 - accuracy: 0.8913
# Epoch 86/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1703 - accuracy: 0.8944
# Epoch 87/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1772 - accuracy: 0.8903
# Epoch 88/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1745 - accuracy: 0.8913
# Epoch 89/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1740 - accuracy: 0.8944
# Epoch 90/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1677 - accuracy: 0.8923
# Epoch 91/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1689 - accuracy: 0.8923
# Epoch 92/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1855 - accuracy: 0.8831
# Epoch 93/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1873 - accuracy: 0.8944
# Epoch 94/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1747 - accuracy: 0.8985
# Epoch 95/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1742 - accuracy: 0.8954
# Epoch 96/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1672 - accuracy: 0.8964
# Epoch 97/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1733 - accuracy: 0.8995
# Epoch 98/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1633 - accuracy: 0.9087
# Epoch 99/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1635 - accuracy: 0.9067
# Epoch 100/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1589 - accuracy: 0.9015
# Epoch 101/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1627 - accuracy: 0.9036
# Epoch 102/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1569 - accuracy: 0.9005
# Epoch 103/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1642 - accuracy: 0.9036
# Epoch 104/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1646 - accuracy: 0.9056
# Epoch 105/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1842 - accuracy: 0.8954
# Epoch 106/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.2001 - accuracy: 0.8882
# Epoch 107/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1780 - accuracy: 0.8985
# Epoch 108/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1705 - accuracy: 0.8995
# Epoch 109/500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.1652 - accuracy: 0.9026
# Epoch 110/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1653 - accuracy: 0.9067
# Epoch 111/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1629 - accuracy: 0.8995
# Epoch 112/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1601 - accuracy: 0.9118
# Epoch 113/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1624 - accuracy: 0.9005
# Epoch 114/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1515 - accuracy: 0.9056
# Epoch 115/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1715 - accuracy: 0.8944
# Epoch 116/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1618 - accuracy: 0.8933
# Epoch 117/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1671 - accuracy: 0.9067
# Epoch 118/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1663 - accuracy: 0.8954
# Epoch 119/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1553 - accuracy: 0.9067
# Epoch 120/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1584 - accuracy: 0.9005
# Epoch 121/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.
500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1379 - accuracy: 0.9097
# Epoch 248/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1363 - accuracy: 0.9087
# Epoch 249/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1365 - accuracy: 0.9118
# Epoch 250/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1385 - accuracy: 0.9138
# Epoch 251/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1375 - accuracy: 0.9169
# Epoch 252/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1383 - accuracy: 0.9149
# Epoch 253/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1336 - accuracy: 0.9118
# Epoch 254/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1325 - accuracy: 0.9200
# Epoch 255/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1379 - accuracy: 0.9149
# Epoch 256/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1371 - accuracy: 0.9149
# Epoch 257/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1316 - accuracy: 0.9149
# Epoch 258/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1428 - accuracy: 0.9087
# Epoch 259/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1280 - accuracy: 0.9313
# Epoch 260/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1383 - accuracy: 0.9108
# Epoch 261/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1358 - accuracy: 0.9272
# Epoch 262/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1393 - accuracy: 0.9087
# Epoch 263/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1327 - accuracy: 0.9159
# Epoch 264/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1337 - accuracy: 0.9077
# Epoch 265/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1326 - accuracy: 0.9067
# Epoch 266/500
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1305 - accuracy: 0.9159
# Epoch 267/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1383 - accuracy: 0.9118
# Epoch 268/500
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1336 - accuracy: 0.9108
# Epoch 269/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1309 - accuracy: 0.9190
# Epoch 270/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1388 - accuracy: 0.9087
# Epoch 271/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1321 - accuracy: 0.9097
# Epoch 272/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1466 - accuracy: 0.8985
# Epoch 273/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1391 - accuracy: 0.9118
# Epoch 274/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1380 - accuracy: 0.9056
# Epoch 275/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1350 - accuracy: 0.9179
# Epoch 276/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1316 - accuracy: 0.9190
# Epoch 277/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1301 - accuracy: 0.9138
# Epoch 278/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1349 - accuracy: 0.9056
# Epoch 279/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1349 - accuracy: 0.9087
# Epoch 280/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1318 - accuracy: 0.9138
# Epoch 281/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1428 - accuracy: 0.9005
# Epoch 282/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1371 - accuracy: 0.9241
# Epoch 283/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1626 - accuracy: 0.9077
# Epoch 284/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1600 - accuracy: 0.9087
# Epoch 285/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1418 - accuracy: 0.9087
# Epoch 286/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1515 - accuracy: 0.9077
# Epoch 287/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1409 - accuracy: 0.9108
# Epoch 288/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1371 - accuracy: 0.9118
# Epoch 289/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1447 - accuracy: 0.9097
# Epoch 290/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1316 - accuracy: 0.9118
# Epoch 291/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1317 - accuracy: 0.9159
# Epoch 292/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1297 - accuracy: 0.9169
# Epoch 293/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1279 - accuracy: 0.9128
# Epoch 294/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1339 - accuracy: 0.9159
# Epoch 295/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1389 - accuracy: 0.9149
# Epoch 296/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1312 - accuracy: 0.9118
# Epoch 297/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1265 - accuracy: 0.9241
# Epoch 298/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1291 - accuracy: 0.9179
# Epoch 299/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1268 - accuracy: 0.9169
# Epoch 300/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1346 - accuracy: 0.9179
# Epoch 301/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1312 - accuracy: 0.9169
# Epoch 302/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1293 - accuracy: 0.9118
# Epoch 303/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1319 - accuracy: 0.9149
# Epoch 304/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1277 - accuracy: 0.9190
# Epoch 305/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1338 - accuracy: 0.9097
# Epoch 306/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1302 - accuracy: 0.9179
# Epoch 307/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1316 - accuracy: 0.9118
# Epoch 308/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1265 - accuracy: 0.9169
# Epoch 309/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1294 - accuracy: 0.9251
# Epoch 310/500
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1266 - accuracy: 0.9149
# Epoch 311/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1273 - accuracy: 0.9118
# Epoch 312/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1267 - accuracy: 0.9210
# Epoch 313/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1299 - accuracy: 0.9169
# Epoch 314/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1292 - accuracy: 0.9128
# Epoch 315/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1292 - accuracy: 0.8995
# Epoch 316/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1294 - accuracy: 0.9097
# Epoch 317/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1260 - accuracy: 0.9179
# Epoch 318/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1271 - accuracy: 0.9138
# Epoch 319/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1281 - accuracy: 0.9179
# Epoch 320/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1246 - accuracy: 0.9138
# Epoch 321/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1232 - accuracy: 0.9159
# Epoch 322/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1261 - accuracy: 0.9190
# Epoch 323/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1350 - accuracy: 0.9138
# Epoch 324/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1356 - accuracy: 0.9108
# Epoch 325/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1259 - accuracy: 0.9221
# Epoch 326/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1247 - accuracy: 0.9210
# Epoch 327/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1237 - accuracy: 0.9231
# Epoch 328/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1279 - accuracy: 0.9169
# Epoch 329/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1270 - accuracy: 0.9169
# Epoch 330/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1275 - accuracy: 0.9067
# Epoch 331/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1277 - accuracy: 0.9221
# Epoch 332/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1313 - accuracy: 0.9149
# Epoch 333/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1273 - accuracy: 0.9108
# Epoch 334/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1234 - accuracy: 0.9159
# Epoch 335/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1226 - accuracy: 0.9190
# Epoch 336/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1224 - accuracy: 0.9210
# Epoch 337/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1244 - accuracy: 0.9221
# Epoch 338/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1252 - accuracy: 0.9077
# Epoch 339/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1262 - accuracy: 0.9190
# Epoch 340/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1257 - accuracy: 0.9179
# Epoch 341/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1271 - accuracy: 0.9128
# Epoch 342/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1326 - accuracy: 0.9149
# Epoch 343/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1298 - accuracy: 0.9200
# Epoch 344/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1285 - accuracy: 0.9169
# Epoch 345/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1293 - accuracy: 0.9190
# Epoch 346/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1237 - accuracy: 0.9190
# Epoch 347/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1233 - accuracy: 0.9179
# Epoch 348/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1518 - accuracy: 0.9087
# Epoch 349/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1648 - accuracy: 0.9056
# Epoch 350/500
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1523 - accuracy: 0.9108
# Epoch 351/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1255 - accuracy: 0.9200
# Epoch 352/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1234 - accuracy: 0.9169
# Epoch 353/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1211 - accuracy: 0.9169
# Epoch 354/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1276 - accuracy: 0.9036
# Epoch 355/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1212 - accuracy: 0.9231
# Epoch 356/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1233 - accuracy: 0.9190
# Epoch 357/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1253 - accuracy: 0.9169
# Epoch 358/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1244 - accuracy: 0.9138
# Epoch 359/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1245 - accuracy: 0.9087
# Epoch 360/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1230 - accuracy: 0.9221
# Epoch 361/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1232 - accuracy: 0.9190
# Epoch 362/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1216 - accuracy: 0.9210
# Epoch 363/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1246 - accuracy: 0.9138
# Epoch 364/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1258 - accuracy: 0.9159
# Epoch 365/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1273 - accuracy: 0.9159
# Epoch 366/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1226 - accuracy: 0.9169
# Epoch 367/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1192 - accuracy: 0.9282
# Epoch 368/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1207 - accuracy: 0.9179
# Epoch 369/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1223 - accuracy: 0.9179
# Epoch 370/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1318 - accuracy: 0.9159
# Epoch 371/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1241 - accuracy: 0.9179
# Epoch 372/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1225 - accuracy: 0.9077
# Epoch 373/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1216 - accuracy: 0.9210
# Epoch 374/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1246 - accuracy: 0.9138
# Epoch 375/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1223 - accuracy: 0.9221
# Epoch 376/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1226 - accuracy: 0.9097
# Epoch 377/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1246 - accuracy: 0.9262
# Epoch 378/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1222 - accuracy: 0.9159
# Epoch 379/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1222 - accuracy: 0.9190
# Epoch 380/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1212 - accuracy: 0.9138
# Epoch 381/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1235 - accuracy: 0.9210
# Epoch 382/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1227 - accuracy: 0.9200
# Epoch 383/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1221 - accuracy: 0.9179
# Epoch 384/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1218 - accuracy: 0.9210
# Epoch 385/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1219 - accuracy: 0.9231
# Epoch 386/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1220 - accuracy: 0.9138
# Epoch 387/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1209 - accuracy: 0.9149
# Epoch 388/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1175 - accuracy: 0.9221
# Epoch 389/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1200 - accuracy: 0.9200
# Epoch 390/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1197 - accuracy: 0.9200
# Epoch 391/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1203 - accuracy: 0.9221
# Epoch 392/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1316 - accuracy: 0.9179
# Epoch 393/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1367 - accuracy: 0.9169
# Epoch 394/500
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1299 - accuracy: 0.9149
# Epoch 395/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1259 - accuracy: 0.9251
# Epoch 396/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1246 - accuracy: 0.9097
# Epoch 397/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1259 - accuracy: 0.9149
# Epoch 398/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1230 - accuracy: 0.9262
# Epoch 399/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1222 - accuracy: 0.9190
# Epoch 400/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1213 - accuracy: 0.9200
# Epoch 401/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1255 - accuracy: 0.9108
# Epoch 402/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1230 - accuracy: 0.9179
# Epoch 403/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1218 - accuracy: 0.9108
# Epoch 404/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1197 - accuracy: 0.9118
# Epoch 405/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1210 - accuracy: 0.9077
# Epoch 406/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1195 - accuracy: 0.9128
# Epoch 407/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1186 - accuracy: 0.9292
# Epoch 408/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1222 - accuracy: 0.9169
# Epoch 409/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1217 - accuracy: 0.9159
# Epoch 410/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1402 - accuracy: 0.9087
# Epoch 411/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1241 - accuracy: 0.9128
# Epoch 412/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1246 - accuracy: 0.9179
# Epoch 413/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1207 - accuracy: 0.9179
# Epoch 414/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1174 - accuracy: 0.9200
# Epoch 415/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1182 - accuracy: 0.9169
# Epoch 416/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1197 - accuracy: 0.9221
# Epoch 417/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1192 - accuracy: 0.9200
# Epoch 418/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1237 - accuracy: 0.9179
# Epoch 419/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1238 - accuracy: 0.9241
# Epoch 420/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1255 - accuracy: 0.9179
# Epoch 421/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1344 - accuracy: 0.9159
# Epoch 422/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1418 - accuracy: 0.9097
# Epoch 423/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1197 - accuracy: 0.9179
# Epoch 424/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1191 - accuracy: 0.9179
# Epoch 425/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1195 - accuracy: 0.9179
# Epoch 426/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1206 - accuracy: 0.9282
# Epoch 427/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1274 - accuracy: 0.9221
# Epoch 428/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1210 - accuracy: 0.9221
# Epoch 429/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1216 - accuracy: 0.9190
# Epoch 430/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1193 - accuracy: 0.9231
# Epoch 431/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1195 - accuracy: 0.9149
# Epoch 432/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1163 - accuracy: 0.9251
# Epoch 433/500
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1162 - accuracy: 0.9282
# Epoch 434/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1189 - accuracy: 0.9149
# Epoch 435/500
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1226 - accuracy: 0.9241
# Epoch 436/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1226 - accuracy: 0.9097
# Epoch 437/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1176 - accuracy: 0.9169
# Epoch 438/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1168 - accuracy: 0.9200
# Epoch 439/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1221 - accuracy: 0.9159
# Epoch 440/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1221 - accuracy: 0.9190
# Epoch 441/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1171 - accuracy: 0.9221
# Epoch 442/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1187 - accuracy: 0.9190
# Epoch 443/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1209 - accuracy: 0.9210
# Epoch 444/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1230 - accuracy: 0.9108
# Epoch 445/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1209 - accuracy: 0.9026
# Epoch 446/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1232 - accuracy: 0.9087
# Epoch 447/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1193 - accuracy: 0.9190
# Epoch 448/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1191 - accuracy: 0.9138
# Epoch 449/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1188 - accuracy: 0.9138
# Epoch 450/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1190 - accuracy: 0.9221
# Epoch 451/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1188 - accuracy: 0.9200
# Epoch 452/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1215 - accuracy: 0.9128
# Epoch 453/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1215 - accuracy: 0.9200
# Epoch 454/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1259 - accuracy: 0.9087
# Epoch 455/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1208 - accuracy: 0.9190
# Epoch 456/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1192 - accuracy: 0.9159
# Epoch 457/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1167 - accuracy: 0.9179
# Epoch 458/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1196 - accuracy: 0.9221
# Epoch 459/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1183 - accuracy: 0.9149
# Epoch 460/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1221 - accuracy: 0.9190
# Epoch 461/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1228 - accuracy: 0.9097
# Epoch 462/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1249 - accuracy: 0.9159
# Epoch 463/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1213 - accuracy: 0.9241
# Epoch 464/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1203 - accuracy: 0.9097
# Epoch 465/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1201 - accuracy: 0.9200
# Epoch 466/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1224 - accuracy: 0.9179
# Epoch 467/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1201 - accuracy: 0.9231
# Epoch 468/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1166 - accuracy: 0.9303
# Epoch 469/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1189 - accuracy: 0.9179
# Epoch 470/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1183 - accuracy: 0.9190
# Epoch 471/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1220 - accuracy: 0.9179
# Epoch 472/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1178 - accuracy: 0.9190
# Epoch 473/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1216 - accuracy: 0.9179
# Epoch 474/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1340 - accuracy: 0.9200
# Epoch 475/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1381 - accuracy: 0.9108
# Epoch 476/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1287 - accuracy: 0.9149
# Epoch 477/500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1242 - accuracy: 0.9159
# Epoch 478/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1187 - accuracy: 0.9231
# Epoch 479/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1168 - accuracy: 0.9159
# Epoch 480/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1246 - accuracy: 0.9190
# Epoch 481/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1178 - accuracy: 0.9210
# Epoch 482/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1222 - accuracy: 0.9128
# Epoch 483/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1195 - accuracy: 0.9210
# Epoch 484/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1167 - accuracy: 0.9200
# Epoch 485/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1160 - accuracy: 0.9221
# Epoch 486/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1177 - accuracy: 0.9241
# Epoch 487/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1179 - accuracy: 0.9251
# Epoch 488/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1183 - accuracy: 0.9231
# Epoch 489/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1199 - accuracy: 0.9190
# Epoch 490/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1245 - accuracy: 0.9179
# Epoch 491/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1207 - accuracy: 0.9221
# Epoch 492/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1213 - accuracy: 0.9169
# Epoch 493/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1197 - accuracy: 0.9159
# Epoch 494/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1192 - accuracy: 0.9169
# Epoch 495/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1211 - accuracy: 0.9138
# Epoch 496/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1190 - accuracy: 0.9251
# Epoch 497/500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1285 - accuracy: 0.9190
# Epoch 498/500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.1245 - accuracy: 0.9046
# Epoch 499/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1201 - accuracy: 0.9169
# Epoch 500/500
# 31/31 [==============================] - 0s 10ms/step - loss: 0.1179 - accuracy: 0.9231

# %% [markdown]
# Dictionary of possible replies by ChatBot based on FAQs

# %%
Query_reply = {"return":"Returns can only be issued within 7 days of delivery."
                        "Electronics can only be replaced,"
                        "Visit my orders page to check for more details as return period may vary for different products."
               ,"payments": "We accept all UPIs and card payments including Visa,MasterCard and Rupay,"
                            "Cash on delivery option is available only for specific products,"
                            "For checking your payments, you can visit transactions section"
               ,"track": "Visit the order page, click on the your order, select 'TRACK MY ORDER', and check the status"
               ,"delivery":"Delivery and shipping takes around 7 days for non-prime users and 2 days for prime users"
                           "If your order has not been delivered for more than above mentioned days, then click on 'URGENT QUERY' in orders section and our team will contact you shortly afterwards."
               ,"items":"We have great range of products, click on CATEGORY drop-down menu to see all our products."
               ,"confirm": "It takes upto 24 hours for confirmation,"
                           "If your order has not been confirmed for more than above mentioned time, then click on 'URGENT QUERY' in orders section and our team will contact you shortly afterwards."
               ,"delay":"We are really sorry if there has been a delay more than the specified period,"
                        "If your order has not been delivered for more than above mentioned days, then click on 'URGENT QUERY' in orders section and our team will contact you shortly afterwards."
               ,"return_status":"It generally takes about 3 days to pickup an order, and around 7 days to initialise the refund after verification and checking of the product."
                                "If you have not received refund even after 10 days, check your wallet balance,due to some bank issues, we sometimes pay into your wallet."
                                 "If there also you have not received the payment,please contact our Customer Care Call support."
               ,"voucher": "You can add a voucher by clicking on VOUCHERS > ADD VOUCHER "
                           "To avail a voucher, click on 'AVAIL VOUCHER' option at the time of payment."
               ,"mobile_app": "You can download the our Mobile App from IOS App Store, or Google Play Store for a better experience."
               ,"cancel": "Order can only be cancelled within 24 hours of the placement of the order."
                          "To cancel an order, go to ORDERS > Cancel An Order "
               ,"goodbye":"Have a nice day. Hope I was able to help!,If your query has not been resolved, please contact our Customer Care Call Centre."
               ,"thanks":"Happy to help!,Anything else in which I can be of assistance?"
               ,"reasons":"Reasons include Courier Issues, Cross Border shipment delay, Non-timely delivery by seller to us."
               ,"profile": "You can add or change your account details by following the steps: "
                           "Account > Click on 'Manage my account' from the icon, You change or edit your name, address, email address, mobile number > click on Update Details."
               ,"more":"Contact our Customer Call Support Centre: Phone: 051-111-128929. Timings are from 09:00 AM to 05:00 PM from Monday to Saturday."
               ,"greeting":"Hello!, How can I help?"
               ,"personal":"I'm good"
               ,"refund_status": "It generally takes upto 14 days to receive into bank."
                                 "If you have not received refund even after 14 days, check your wallet balance,due to some bank issues, we sometimes pay into your wallet."
                                 "If there also you have not received the payment,please contact our Customer Care Call support."}

# %% [markdown]
# ## ChatBot Implementation via Terminal

# %% [markdown]
# ## For better results and experience, use Google Colab or Jupyter Notebook

# %% [markdown]
# ### Run only below cell instead of whole code when using repeatedly as that would result in updating our model with more and more use.

# %% [markdown]
# ## Improving the Bot after every 20 successful predictions

# %% [markdown]
# ### Also, updating these new values to our dataset

# %%
user_has_query = True
corpus_update = 0
corpus_new = []
y_new = []
userInput_list = []

while user_has_query:
    textList = []
    prediction_input = []
    response_tag = ""
    print("Greetings!, how can I help?")
    print("To end a conversation, type 'goodbye'.")
    userInput = input("You: ")
    user_input = clean_text(userInput)
    user_input = user_input.split()
    user_input = [ps.stem(word) for word in user_input]
    user_input = " ".join(user_input)

    for i in range(len(corpus_new)):
        if user_input == corpus_new[i]:
            response_tag = y_new[i]

    if response_tag != "":
        print("Chatbot: ",Query_reply[response_tag])
    else:
        textList.append(user_input)
        prediction_input = tokenizer.texts_to_sequences(textList)
        prediction_input = np.array(prediction_input).reshape(-1)
        prediction_input = pad_sequences([prediction_input], input_shape)

        output = model.predict(prediction_input)
        import math
        probability = []
        sum_exp = 0
        for i in range(19):
            sum_exp += math.exp(output[0][i])
        for i in range(19):
            prob = math.exp(output[0][i])/sum_exp
            probability.append(prob)
# Minimum confidence = 10%.
        if max(probability)>0.1:
            arg = output.argmax()
            response_tag = le.inverse_transform([arg])[0]
#             print(max(probability)*100,'%')
        else:
            response_tag = 'more'
        print("Chatbot: ",Query_reply[response_tag])

    if response_tag == "goodbye":
            user_has_query = False
    else:
# Updating our chatbot to remember the current reply if that was correct for future.
        ask_user = input('Was my response helpful?: ')
        if ask_user == "yes":
            corpus_update += 1
            corpus_new.append(user_input)
            y_new.append(response_tag)
            userInput_list.append(userInput)
        else:
            ask_user_again = input('Your query is related to which category? '
                                    ,['return','payments','track','delivery','items','confirm','delay','return_status','voucher','mobile_app','cancel','reasons','profile','refund status'])
            if ask_user_again in Query_reply:
              for query in Query_reply:
                if ask_user_again == query:
                  user_input_new = ask_user_again
                  response_tag_new = query
            else:
              user_input_new = clean_text(ask_user_again)
              user_input_new = user_input_new.split()
              user_input_new = [ps.stem(word) for word in user_input_new]
              user_input_new = " ".join(user_input_new)
              prediction_input_new = tokenizer.texts_to_sequences([user_input_new])
              prediction_input_new = np.array(prediction_input_new).reshape(-1)
              prediction_input_new = pad_sequences([prediction_input_new], input_shape)
              output_new = model.predict(prediction_input_new)
              arg_new = output_new.argmax()
              response_tag_new = le.inverse_transform([arg_new])[0]
            print("Chatbot: ",Query_reply[response_tag_new])
            ask_user_new = input('Was my response helpful now?: ')
            if ask_user_new == "yes":
              corpus_update += 1
              corpus_new.append(user_input_new)
              y_new.append(response_tag_new)
              userInput_list.append(ask_user_again)
              y_new.append(response_tag_new)
              userInput_list.append(userInput)
            else:
              print('I am sorry')
              print('Please contact our costumer service call centre')

# Bot Upgradation after 20 successful predictions.

if corpus_update >=25:
    corpus += corpus_new
    y += y_new
    model.fit(pad_sequences(tokenizer.texts_to_sequences(corpus)), le.fit_transform(y), epochs=500)
    for i in range(corpus_update):
      new_data = []
      new_data.append({'Queries':userInput_list[i], 'Type':y_new[i]})
      dataset = dataset.append(new_data,ignore_index=True)

    userInput_list = []
    corpus_update = 0
    corpus = corpus_new
    y = y_new
    y_new = []
    corpus_new = []

    dataset.to_csv('Customer_Queries_1.csv',index=False)
# Out:
# Greetings!, how can I help?
# To end a conversation, type 'goodbye'.

# %%
for query in Query_reply:
  print(query)
